# %%
gold_notebooks = [
    "./01_build_dim_date",
    "./02_build_dim_location_scd2",
    "./03_build_dim_vendor",
    "./04_build_dim_weather",
    "./05_build_fact_trips",
    "./06_build_fact_trips_streaming"
]
# Timeout defined in seconds (3600 = 1 hour)
for notebook in gold_notebooks:
    print(f"Starting {notebook}...")
    status = dbutils.notebook.run(notebook, 3600)
    print(f"Finished {notebook}: {status}")
